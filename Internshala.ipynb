# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from urllib.request import urlopen
import pandas as pd

# %%
html = '<ul class="chosen-results"><li class="active-result" data-option-array-index="0">.NET Development</li><li class="active-result" data-option-array-index="1">Accounts</li><li class="active-result" data-option-array-index="2">Aerospace Engineering</li><li class="active-result" data-option-array-index="3">Agriculture &amp; Food Engineering</li><li class="active-result" data-option-array-index="4">Analytics</li><li class="active-result" data-option-array-index="5">Anchoring</li><li class="active-result" data-option-array-index="6">Android App Development</li><li class="active-result" data-option-array-index="7">Angular.js Development</li><li class="active-result" data-option-array-index="8">Animation</li><li class="active-result" data-option-array-index="9">Architecture</li><li class="active-result" data-option-array-index="10">Artificial Intelligence (AI)</li><li class="active-result" data-option-array-index="11">ASP.NET Development</li><li class="active-result" data-option-array-index="12">Audio Making/Editing</li><li class="active-result" data-option-array-index="13">Backend Development</li><li class="active-result" data-option-array-index="14">Big Data</li><li class="active-result" data-option-array-index="15">Bioinformatics</li><li class="active-result" data-option-array-index="16">Biology</li><li class="active-result" data-option-array-index="17">Biotechnology Engineering</li><li class="active-result" data-option-array-index="18">Blockchain Development</li><li class="active-result" data-option-array-index="19">Blogging</li><li class="active-result" data-option-array-index="20">Brand Management</li><li class="active-result" data-option-array-index="21">Business/MBA</li><li class="active-result" data-option-array-index="22">CAD Design</li><li class="active-result" data-option-array-index="23">Campus Ambassador</li><li class="active-result" data-option-array-index="24">Chartered Accountancy (CA)</li><li class="active-result" data-option-array-index="25">Chemical Engineering</li><li class="active-result" data-option-array-index="26">Chemistry</li><li class="active-result" data-option-array-index="27">Cinematography</li><li class="active-result" data-option-array-index="28">Civil Engineering</li><li class="active-result" data-option-array-index="29">Client Servicing</li><li class="active-result" data-option-array-index="30">Cloud Computing</li><li class="active-result" data-option-array-index="31">Commerce</li><li class="active-result" data-option-array-index="32">Company Secretary (CS)</li><li class="active-result" data-option-array-index="33">Computer Science</li><li class="active-result" data-option-array-index="34">Computer Vision</li><li class="active-result" data-option-array-index="35">Content Writing</li><li class="active-result" data-option-array-index="36">Copywriting</li><li class="active-result" data-option-array-index="37">Creative Writing</li><li class="active-result" data-option-array-index="38">Culinary Arts</li><li class="active-result" data-option-array-index="39">Customer Service</li><li class="active-result" data-option-array-index="40">Cyber Security</li><li class="active-result" data-option-array-index="41">Data Entry</li><li class="active-result" data-option-array-index="42">Data Science</li><li class="active-result" data-option-array-index="43">Database Building</li><li class="active-result" data-option-array-index="44">Design</li><li class="active-result" data-option-array-index="45">Dietetics/Nutrition</li><li class="active-result" data-option-array-index="46">Digital Marketing</li><li class="active-result" data-option-array-index="47">Editorial</li><li class="active-result" data-option-array-index="48">Electrical Engineering</li><li class="active-result" data-option-array-index="49">Electronics Engineering</li><li class="active-result" data-option-array-index="50">Embedded Systems</li><li class="active-result" data-option-array-index="51">Engineering</li><li class="active-result" data-option-array-index="52">Engineering Design</li><li class="active-result" data-option-array-index="53">Environmental Sciences</li><li class="active-result" data-option-array-index="54">Event Management</li><li class="active-result" data-option-array-index="55">Fashion Design</li><li class="active-result" data-option-array-index="56">Film Making</li><li class="active-result" data-option-array-index="57">Finance</li><li class="active-result" data-option-array-index="58">Flutter Development</li><li class="active-result" data-option-array-index="59">Front End Development</li><li class="active-result" data-option-array-index="60">Full Stack Development</li><li class="active-result" data-option-array-index="61">Fundraising</li><li class="active-result" data-option-array-index="62">Game Development</li><li class="active-result" data-option-array-index="63">General Management</li><li class="active-result" data-option-array-index="64">Government</li><li class="active-result" data-option-array-index="65">Graphic Design</li><li class="active-result" data-option-array-index="66">Hospitality</li><li class="active-result" data-option-array-index="67">Hotel Management</li><li class="active-result" data-option-array-index="68">Human Resources (HR)</li><li class="active-result" data-option-array-index="69">Humanities</li><li class="active-result" data-option-array-index="70">Industrial &amp; Production Engineering</li><li class="active-result" data-option-array-index="71">Industrial Design</li><li class="active-result" data-option-array-index="72">Information Technology</li><li class="active-result" data-option-array-index="73">Instrumentation &amp; Control Engineering</li><li class="active-result" data-option-array-index="74">Interior Design</li><li class="active-result" data-option-array-index="75">Internet of Things (IoT)</li><li class="active-result" data-option-array-index="76">iOS App Development</li><li class="active-result" data-option-array-index="77">Java Development</li><li class="active-result" data-option-array-index="78">Javascript Development</li><li class="active-result" data-option-array-index="79">Journalism</li><li class="active-result" data-option-array-index="80">Law</li><li class="active-result" data-option-array-index="81">Legal Research</li><li class="active-result" data-option-array-index="82">Machine Learning</li><li class="active-result" data-option-array-index="83">Magento Development</li><li class="active-result" data-option-array-index="84">Market/Business Research</li><li class="active-result" data-option-array-index="85">Marketing/Sales</li><li class="active-result" data-option-array-index="86">Mathematics</li><li class="active-result" data-option-array-index="87">Mechanical Engineering</li><li class="active-result" data-option-array-index="88">Mechatronics</li><li class="active-result" data-option-array-index="89">Media</li><li class="active-result" data-option-array-index="90">Medicine</li><li class="active-result" data-option-array-index="91">Merchandise Design</li><li class="active-result" data-option-array-index="92">Metallurgical Engineering</li><li class="active-result" data-option-array-index="93">Mobile App Development</li><li class="active-result" data-option-array-index="94">Motion Graphics</li><li class="active-result" data-option-array-index="95">Music</li><li class="active-result" data-option-array-index="96">Network Engineering</li><li class="active-result" data-option-array-index="97">NGO</li><li class="active-result" data-option-array-index="98">Node.js Development</li><li class="active-result" data-option-array-index="99">Operations</li><li class="active-result" data-option-array-index="100">Pharmaceutical</li><li class="active-result" data-option-array-index="101">Photography</li><li class="active-result" data-option-array-index="102">PHP Development</li><li class="active-result" data-option-array-index="103">Physics</li><li class="active-result" data-option-array-index="104">Political/Economics/Policy Research</li><li class="active-result" data-option-array-index="105">Product Management</li><li class="active-result" data-option-array-index="106">Programming</li><li class="active-result" data-option-array-index="107">Project Management</li><li class="active-result" data-option-array-index="108">Proofreading</li><li class="active-result" data-option-array-index="109">Psychology</li><li class="active-result" data-option-array-index="110">Public Relations (PR)</li><li class="active-result" data-option-array-index="111">Python/Django Development</li><li class="active-result" data-option-array-index="112">Quality Analyst</li><li class="active-result" data-option-array-index="113">Recruitment</li><li class="active-result" data-option-array-index="114">Ruby on Rails</li><li class="active-result" data-option-array-index="115">Science</li><li class="active-result" data-option-array-index="116">Search Engine Optimization (SEO)</li><li class="active-result" data-option-array-index="117">Social Media Marketing</li><li class="active-result" data-option-array-index="118">Social Work</li><li class="active-result" data-option-array-index="119">Software Development</li><li class="active-result" data-option-array-index="120">Software Testing</li><li class="active-result" data-option-array-index="121">Statistics</li><li class="active-result" data-option-array-index="122">Strategy</li><li class="active-result" data-option-array-index="123">Subject Matter Expert (SME)</li><li class="active-result" data-option-array-index="124">Supply Chain Management (SCM)</li><li class="active-result" data-option-array-index="125">Talent Acquisition</li><li class="active-result" data-option-array-index="126">Teaching</li><li class="active-result" data-option-array-index="127">Telecalling</li><li class="active-result" data-option-array-index="128">Transcription</li><li class="active-result" data-option-array-index="129">Translation</li><li class="active-result" data-option-array-index="130">Travel &amp; Tourism</li><li class="active-result" data-option-array-index="131">UI/UX Design</li><li class="active-result" data-option-array-index="132">Video Making/Editing</li><li class="active-result" data-option-array-index="133">Videography</li><li class="active-result" data-option-array-index="134">Volunteering</li><li class="active-result" data-option-array-index="135">Web Development</li><li class="active-result" data-option-array-index="136">Wordpress Development</li></ul>'
soup = BeautifulSoup(html, "html.parser")
categories = [category.text.strip() for category in soup.find_all("li", class_="active-result")]
categories = pd.DataFrame(categories)
categories.to_csv("categories.csv", index=False)

# %%
html2 = f'<div class="chosen-drop"><ul class="chosen-results" style="display: block;"><li class="active-result" data-option-array-index="0">Agra</li><li class="active-result" data-option-array-index="1">Ahemdabad Kasora</li><li class="active-result" data-option-array-index="2">Ahmadabad</li><li class="active-result" data-option-array-index="3">Ahmedabad</li><li class="active-result" data-option-array-index="4">Ahmednagar</li><li class="active-result" data-option-array-index="5">Ajmer</li><li class="active-result" data-option-array-index="6">Akola</li><li class="active-result" data-option-array-index="7">Alappuzha</li><li class="active-result" data-option-array-index="8">Alibag</li><li class="active-result" data-option-array-index="9">Alwar</li><li class="active-result" data-option-array-index="10">Amalapuram</li><li class="active-result" data-option-array-index="11">Amaravathi</li><li class="active-result" data-option-array-index="12">Amaravati</li><li class="active-result" data-option-array-index="13">Ambala</li><li class="active-result" data-option-array-index="14">Ambernath</li><li class="active-result" data-option-array-index="15">Ameerpet</li><li class="active-result" data-option-array-index="16">Amravati</li><li class="active-result" data-option-array-index="17">Amritsar</li><li class="active-result" data-option-array-index="18">Amroha</li><li class="active-result" data-option-array-index="19">Anakapalle</li><li class="active-result" data-option-array-index="20">Anand</li><li class="active-result" data-option-array-index="21">Anantapur</li><li class="active-result" data-option-array-index="22">Anantapuram</li><li class="active-result" data-option-array-index="23">Andhra Pradesh</li><li class="active-result" data-option-array-index="24">Andra</li><li class="active-result" data-option-array-index="25">Angamaly</li><li class="active-result" data-option-array-index="26">Anjuna</li><li class="active-result" data-option-array-index="27">Asansol</li><li class="active-result" data-option-array-index="28">Assam</li><li class="active-result" data-option-array-index="29">Aundh</li><li class="active-result" data-option-array-index="30">Aurangabad</li><li class="active-result" data-option-array-index="31">Avinashi</li><li class="active-result" data-option-array-index="32">Ayodhya</li><li class="active-result" data-option-array-index="33">Baddi</li><li class="active-result" data-option-array-index="34">Badgaon</li><li class="active-result" data-option-array-index="35">Badhani</li><li class="active-result" data-option-array-index="36">Badlapur</li><li class="active-result" data-option-array-index="37">Badmal</li><li class="active-result" data-option-array-index="38">Bagalur</li><li class="active-result" data-option-array-index="39">Bahadurgarh</li><li class="active-result" data-option-array-index="40">Balewadi</li><li class="active-result" data-option-array-index="41">Ballari</li><li class="active-result" data-option-array-index="42">Ballia</li><li class="active-result" data-option-array-index="43">Bandapura</li><li class="active-result" data-option-array-index="44">Bandra</li><li class="active-result" data-option-array-index="45">Bangalore</li><li class="active-result" data-option-array-index="46">Bangarapet</li><li class="active-result" data-option-array-index="47">Bardhaman</li><li class="active-result" data-option-array-index="48">Barmer</li><li class="active-result" data-option-array-index="49">Bathinda</li><li class="active-result" data-option-array-index="50">Bawal</li><li class="active-result" data-option-array-index="51">Bediya</li><li class="active-result" data-option-array-index="52">Beed</li><li class="active-result" data-option-array-index="53">Begumpet</li><li class="active-result" data-option-array-index="54">Belapur</li><li class="active-result" data-option-array-index="55">Belgaum</li><li class="active-result" data-option-array-index="56">Bellary</li><li class="active-result" data-option-array-index="57">Betul</li><li class="active-result" data-option-array-index="58">Bharuch</li><li class="active-result" data-option-array-index="59">Bhavnagar</li><li class="active-result" data-option-array-index="60">Bhilai</li><li class="active-result" data-option-array-index="61">Bhilwara</li><li class="active-result" data-option-array-index="62">Bhiwadi</li><li class="active-result" data-option-array-index="63">Bhiwandi</li><li class="active-result" data-option-array-index="64">Bhopal</li><li class="active-result" data-option-array-index="65">Bhopali</li><li class="active-result" data-option-array-index="66">Bhubaneswar</li><li class="active-result" data-option-array-index="67">Bidhan Nagar</li><li class="active-result" data-option-array-index="68">Bihar</li><li class="active-result" data-option-array-index="69">Bikaner</li><li class="active-result" data-option-array-index="70">Birbhum</li><li class="active-result" data-option-array-index="71">Bishalgarh</li><li class="active-result" data-option-array-index="72">Bokaro</li><li class="active-result" data-option-array-index="73">Bokaro Steel City</li><li class="active-result" data-option-array-index="74">Bombay</li><li class="active-result" data-option-array-index="75">Calangute</li><li class="active-result" data-option-array-index="76">Chandigarh</li><li class="active-result" data-option-array-index="77">Chandivali</li><li class="active-result" data-option-array-index="78">Chengalpattu</li><li class="active-result" data-option-array-index="79">Chennai</li><li class="active-result" data-option-array-index="80">Chhattisgarh</li><li class="active-result" data-option-array-index="81">Chikhali</li><li class="active-result" data-option-array-index="82">Chinchawad</li><li class="active-result" data-option-array-index="83">Chiplun</li><li class="active-result" data-option-array-index="84">Chittoor</li><li class="active-result" data-option-array-index="85">City Of Sochi</li><li class="active-result" data-option-array-index="86">Cochin</li><li class="active-result" data-option-array-index="87">Coimbatore</li><li class="active-result" data-option-array-index="88">Cuttack</li><li class="active-result" data-option-array-index="89">Dadra And Nagar Haveli</li><li class="active-result" data-option-array-index="90">Dahisar</li><li class="active-result" data-option-array-index="91">Dakshina Kannada</li><li class="active-result" data-option-array-index="92">Dapoli</li><li class="active-result" data-option-array-index="93">Darjeeling</li><li class="active-result" data-option-array-index="94">Dehradun</li><li class="active-result" data-option-array-index="95">Delhi</li><li class="active-result" data-option-array-index="96">Dera Bassi</li><li class="active-result" data-option-array-index="97">Derabassi</li><li class="active-result" data-option-array-index="98">Dewas</li><li class="active-result" data-option-array-index="99">Dhalai</li><li class="active-result" data-option-array-index="100">Dhanbad</li><li class="active-result" data-option-array-index="101">Dhankawadi</li><li class="active-result" data-option-array-index="102">Dhanori</li><li class="active-result" data-option-array-index="103">Dharamshala</li><li class="active-result" data-option-array-index="104">Dharuhera</li><li class="active-result" data-option-array-index="105">Dharwad</li><li class="active-result" data-option-array-index="106">Dibrugarh</li><li class="active-result" data-option-array-index="107">Dighi</li><li class="active-result" data-option-array-index="108">Dindigul</li><li class="active-result" data-option-array-index="109">Dispur</li><li class="active-result" data-option-array-index="110">District D\'Ernakulam</li><li class="active-result" data-option-array-index="111">District De Mumbai-ville</li><li class="active-result" data-option-array-index="112">Dmitrovsky District</li><li class="active-result" data-option-array-index="113">Doiwala</li><li class="active-result" data-option-array-index="114">Dombivili</li><li class="active-result" data-option-array-index="115">Dombivli</li><li class="active-result" data-option-array-index="116">Durg</li><li class="active-result" data-option-array-index="117">Durgapur</li><li class="active-result" data-option-array-index="118">East Godavari</li><li class="active-result" data-option-array-index="119">East Khasi Hills</li><li class="active-result" data-option-array-index="120">East Singhbhum</li><li class="active-result" data-option-array-index="121">Ernakulam</li><li class="active-result" data-option-array-index="122">Erode</li><li class="active-result" data-option-array-index="123">Faizabad</li><li class="active-result" data-option-array-index="124">Faridabad</li><li class="active-result" data-option-array-index="125">Federal Territory Of Kuala Lumpur</li><li class="active-result" data-option-array-index="126">Gandhinagar</li><li class="active-result" data-option-array-index="127">Ganganagar</li><li class="active-result" data-option-array-index="128">Gangapur City</li><li class="active-result" data-option-array-index="129">Gautam Buddh Nagar</li><li class="active-result" data-option-array-index="130">Gautam Buddha Nagar</li><li class="active-result" data-option-array-index="131">Ghaziabad</li><li class="active-result" data-option-array-index="132">Girgaon</li><li class="active-result" data-option-array-index="133">Giridih</li><li class="active-result" data-option-array-index="134">Goa</li><li class="active-result" data-option-array-index="135">Gorakhpur</li><li class="active-result" data-option-array-index="136">Greater Noida</li><li class="active-result" data-option-array-index="137">Gujarat</li><li class="active-result" data-option-array-index="138">Gujrat</li><li class="active-result" data-option-array-index="139">Gulbarga</li><li class="active-result" data-option-array-index="140">Guntur</li><li class="active-result" data-option-array-index="141">Gurgaon</li><li class="active-result" data-option-array-index="142">Guwahati</li><li class="active-result" data-option-array-index="143">Gwalior</li><li class="active-result" data-option-array-index="144">Gwalior West</li><li class="active-result" data-option-array-index="145">Haridwar</li><li class="active-result" data-option-array-index="146">Haryana</li><li class="active-result" data-option-array-index="147">Hassan</li><li class="active-result" data-option-array-index="148">Himachal Pradesh</li><li class="active-result" data-option-array-index="149">Hoshiarpur</li><li class="active-result" data-option-array-index="150">Hosur</li><li class="active-result" data-option-array-index="151">Howrah</li><li class="active-result" data-option-array-index="152">Hubballi</li><li class="active-result" data-option-array-index="153">Hubli</li><li class="active-result" data-option-array-index="154">Hyderabad</li><li class="active-result" data-option-array-index="155">Idukki</li><li class="active-result" data-option-array-index="156">Indiranagara</li><li class="active-result" data-option-array-index="157">Indore</li><li class="active-result" data-option-array-index="158">Jabalpur</li><li class="active-result" data-option-array-index="159">Jaipur</li><li class="active-result" data-option-array-index="160">Jalandhar</li><li class="active-result" data-option-array-index="161">Jalna</li><li class="active-result" data-option-array-index="162">Jalore</li><li class="active-result" data-option-array-index="163">Jamnagar</li><li class="active-result" data-option-array-index="164">Jamshedpur</li><li class="active-result" data-option-array-index="165">Jhajjar</li><li class="active-result" data-option-array-index="166">Jharkhand</li><li class="active-result" data-option-array-index="167">Jharkhandi</li><li class="active-result" data-option-array-index="168">Jodhpur</li><li class="active-result" data-option-array-index="169">Junagadh</li><li class="active-result" data-option-array-index="170">Kalamboli</li><li class="active-result" data-option-array-index="171">Kalbadevi</li><li class="active-result" data-option-array-index="172">Kalimpong</li><li class="active-result" data-option-array-index="173">Kalyan</li><li class="active-result" data-option-array-index="174">Kamrup</li><li class="active-result" data-option-array-index="175">Kamrup Metropolitan</li><li class="active-result" data-option-array-index="176">Kanchipuram</li><li class="active-result" data-option-array-index="177">Kangra</li><li class="active-result" data-option-array-index="178">Kanhangad</li><li class="active-result" data-option-array-index="179">Kannur</li><li class="active-result" data-option-array-index="180">Kanpur</li><li class="active-result" data-option-array-index="181">Kanpur Dehat</li><li class="active-result" data-option-array-index="182">Kanyakumari</li><li class="active-result" data-option-array-index="183">Karad</li><li class="active-result" data-option-array-index="184">Karimnagar</li><li class="active-result" data-option-array-index="185">Karnal</li><li class="active-result" data-option-array-index="186">Karnataka</li><li class="active-result" data-option-array-index="187">Kasaragod</li><li class="active-result" data-option-array-index="188">Kasol</li><li class="active-result" data-option-array-index="189">Katni</li><li class="active-result" data-option-array-index="190">Kaushambi</li><li class="active-result" data-option-array-index="191">Kengeri Gollahalli</li><li class="active-result" data-option-array-index="192">Kerala</li><li class="active-result" data-option-array-index="193">Kerala Estate</li><li class="active-result" data-option-array-index="194">Keralapuram</li><li class="active-result" data-option-array-index="195">Khammam</li><li class="active-result" data-option-array-index="196">Kharar</li><li class="active-result" data-option-array-index="197">Khargone</li><li class="active-result" data-option-array-index="198">Khordha</li><li class="active-result" data-option-array-index="199">Kinnaur</li><li class="active-result" data-option-array-index="200">Kochi</li><li class="active-result" data-option-array-index="201">Kodad</li><li class="active-result" data-option-array-index="202">Kodagu</li><li class="active-result" data-option-array-index="203">Kodambakkam</li><li class="active-result" data-option-array-index="204">Kodungallur</li><li class="active-result" data-option-array-index="205">Kolar</li><li class="active-result" data-option-array-index="206">Kolhapur</li><li class="active-result" data-option-array-index="207">Kolkata</li><li class="active-result" data-option-array-index="208">Kollam</li><li class="active-result" data-option-array-index="209">Koramangala</li><li class="active-result" data-option-array-index="210">Kota</li><li class="active-result" data-option-array-index="211">Kottakkal</li><li class="active-result" data-option-array-index="212">Kottayam</li><li class="active-result" data-option-array-index="213">Kozhikode</li><li class="active-result" data-option-array-index="214">Kozhikode North</li><li class="active-result" data-option-array-index="215">Kozhikode Sub-District</li><li class="active-result" data-option-array-index="216">Krasnodar Krai</li><li class="active-result" data-option-array-index="217">Krishna</li><li class="active-result" data-option-array-index="218">Krishnagiri</li><li class="active-result" data-option-array-index="219">Kuala Lumpur</li><li class="active-result" data-option-array-index="220">Kukatpalle</li><li class="active-result" data-option-array-index="221">Kullu</li><li class="active-result" data-option-array-index="222">Kumbakonam</li><li class="active-result" data-option-array-index="223">Kundli</li><li class="active-result" data-option-array-index="224">Kurla</li><li class="active-result" data-option-array-index="225">Kurnool</li><li class="active-result" data-option-array-index="226">Kurukshetra</li><li class="active-result" data-option-array-index="227">Lalru</li><li class="active-result" data-option-array-index="228">Latur</li><li class="active-result" data-option-array-index="229">Lucknow</li><li class="active-result" data-option-array-index="230">Ludhiana</li><li class="active-result" data-option-array-index="231">Madhapur</li><li class="active-result" data-option-array-index="232">Madhya Pradesh</li><li class="active-result" data-option-array-index="233">Madikeri</li><li class="active-result" data-option-array-index="234">Madurai</li><li class="active-result" data-option-array-index="235">Mahad</li><li class="active-result" data-option-array-index="236">Mahalaxmi</li><li class="active-result" data-option-array-index="237">Maharashtra</li><li class="active-result" data-option-array-index="238">Maharasztra</li><li class="active-result" data-option-array-index="239">Malakpet</li><li class="active-result" data-option-array-index="240">Malappuram</li><li class="active-result" data-option-array-index="241">Malur</li><li class="active-result" data-option-array-index="242">Mandideep</li><li class="active-result" data-option-array-index="243">Mandla</li><li class="active-result" data-option-array-index="244">Manesar</li><li class="active-result" data-option-array-index="245">Mangalore</li><li class="active-result" data-option-array-index="246">Mangaluru</li><li class="active-result" data-option-array-index="247">Mangaon</li><li class="active-result" data-option-array-index="248">Medak</li><li class="active-result" data-option-array-index="249">Meerut</li><li class="active-result" data-option-array-index="250">Meghalaya</li><li class="active-result" data-option-array-index="251">Mhow</li><li class="active-result" data-option-array-index="252">Mira Bhayandar</li><li class="active-result" data-option-array-index="253">Miyapur</li><li class="active-result" data-option-array-index="254">Mohali</li><li class="active-result" data-option-array-index="255">Moradabad</li><li class="active-result" data-option-array-index="256">Moscow Oblast</li><li class="active-result" data-option-array-index="257">Mulshi</li><li class="active-result" data-option-array-index="258">Mumbai</li><li class="active-result" data-option-array-index="259">Munnar</li><li class="active-result" data-option-array-index="260">Muradabad</li><li class="active-result" data-option-array-index="261">Muzaffarnagar</li><li class="active-result" data-option-array-index="262">Mysuru</li><li class="active-result" data-option-array-index="263">Nagaon</li><li class="active-result" data-option-array-index="264">Nagercoil</li><li class="active-result" data-option-array-index="265">Nagpur</li><li class="active-result" data-option-array-index="266">Nagpura</li><li class="active-result" data-option-array-index="267">Nainital</li><li class="active-result" data-option-array-index="268">Nala Sopara</li><li class="active-result" data-option-array-index="269">Nalgonda</li><li class="active-result" data-option-array-index="270">Nanded</li><li class="active-result" data-option-array-index="271">Nashik</li><li class="active-result" data-option-array-index="272">Navi Mumbai</li><li class="active-result" data-option-array-index="273">Navsari</li><li class="active-result" data-option-array-index="274">Nedumangad</li><li class="active-result" data-option-array-index="275">Nellore</li><li class="active-result" data-option-array-index="276">Nerul</li><li class="active-result" data-option-array-index="277">New Delhi</li><li class="active-result" data-option-array-index="278">New Town</li><li class="active-result" data-option-array-index="279">Nizamabad</li><li class="active-result" data-option-array-index="280">Noida</li><li class="active-result" data-option-array-index="281">North</li><li class="active-result" data-option-array-index="282">North 24 Parganas</li><li class="active-result" data-option-array-index="283">North Goa</li><li class="active-result" data-option-array-index="284">North West</li><li class="active-result" data-option-array-index="285">Nungambakkam</li><li class="active-result" data-option-array-index="286">Odhav</li><li class="active-result" data-option-array-index="287">Odisha</li><li class="active-result" data-option-array-index="288">Osmanabad</li><li class="active-result" data-option-array-index="289">Palakkad</li><li class="active-result" data-option-array-index="290">Pali</li><li class="active-result" data-option-array-index="291">Palwal</li><li class="active-result" data-option-array-index="292">Panaji</li><li class="active-result" data-option-array-index="293">Panchkula</li><li class="active-result" data-option-array-index="294">Panipat</li><li class="active-result" data-option-array-index="295">Panjagutta Colony</li><li class="active-result" data-option-array-index="296">Panjim</li><li class="active-result" data-option-array-index="297">Panvel</li><li class="active-result" data-option-array-index="298">Pashchim Champaran</li><li class="active-result" data-option-array-index="299">Pathanamthitta</li><li class="active-result" data-option-array-index="300">Pathankot</li><li class="active-result" data-option-array-index="301">Patiala</li><li class="active-result" data-option-array-index="302">Patna</li><li class="active-result" data-option-array-index="303">Peeragarhi</li><li class="active-result" data-option-array-index="304">Pen</li><li class="active-result" data-option-array-index="305">Pimpri-Chinchwad</li><li class="active-result" data-option-array-index="306">Pitampura</li><li class="active-result" data-option-array-index="307">Pithampur</li><li class="active-result" data-option-array-index="308">Pollachi</li><li class="active-result" data-option-array-index="309">Prayagraj</li><li class="active-result" data-option-array-index="310">Provincia Di Belluno</li><li class="active-result" data-option-array-index="311">Pune</li><li class="active-result" data-option-array-index="312">Punj</li><li class="active-result" data-option-array-index="313">Punjab</li><li class="active-result" data-option-array-index="314">Raichur</li><li class="active-result" data-option-array-index="315">Raigad</li><li class="active-result" data-option-array-index="316">Raigarh</li><li class="active-result" data-option-array-index="317">Raipur</li><li class="active-result" data-option-array-index="318">Raisen</li><li class="active-result" data-option-array-index="319">Rajahmundry</li><li class="active-result" data-option-array-index="320">Rajarhat</li><li class="active-result" data-option-array-index="321">Rajasthan</li><li class="active-result" data-option-array-index="322">Rajkot</li><li class="active-result" data-option-array-index="323">Rajpura</li><li class="active-result" data-option-array-index="324">Ranchi</li><li class="active-result" data-option-array-index="325">Ranga Reddy</li><li class="active-result" data-option-array-index="326">Ratnagiri</li><li class="active-result" data-option-array-index="327">Renukoot</li><li class="active-result" data-option-array-index="328">Rewa</li><li class="active-result" data-option-array-index="329">Rewari</li><li class="active-result" data-option-array-index="330">Rishikesh</li><li class="active-result" data-option-array-index="331">Riyadh</li><li class="active-result" data-option-array-index="332">Riyadh Province</li><li class="active-result" data-option-array-index="333">Roha</li><li class="active-result" data-option-array-index="334">Rohtak</li><li class="active-result" data-option-array-index="335">Rudrapur</li><li class="active-result" data-option-array-index="336">Russia</li><li class="active-result" data-option-array-index="337">Sagar</li><li class="active-result" data-option-array-index="338">Saharanpur</li><li class="active-result" data-option-array-index="339">Sahibzada Ajit Singh Nagar</li><li class="active-result" data-option-array-index="340">Salem</li><li class="active-result" data-option-array-index="341">Samalkha</li><li class="active-result" data-option-array-index="342">Sambalpur</li><li class="active-result" data-option-array-index="343">Sangareddy</li><li class="active-result" data-option-array-index="344">Sangla</li><li class="active-result" data-option-array-index="345">Sangli</li><li class="active-result" data-option-array-index="346">Sangrur</li><li class="active-result" data-option-array-index="347">Satara</li><li class="active-result" data-option-array-index="348">Satna</li><li class="active-result" data-option-array-index="349">Sawai Madhopur</li><li class="active-result" data-option-array-index="350">Secunderabad</li><li class="active-result" data-option-array-index="351">Sehore</li><li class="active-result" data-option-array-index="352">Shakti Nagar</li><li class="active-result" data-option-array-index="353">Shamli</li><li class="active-result" data-option-array-index="354">Shikrapur</li><li class="active-result" data-option-array-index="355">Shillong</li><li class="active-result" data-option-array-index="356">Shirur</li><li class="active-result" data-option-array-index="357">Sikar</li><li class="active-result" data-option-array-index="358">Siliguri</li><li class="active-result" data-option-array-index="359">Silvassa</li><li class="active-result" data-option-array-index="360">Sindhudurg</li><li class="active-result" data-option-array-index="361">Singrauli</li><li class="active-result" data-option-array-index="362">Sion Koliwada</li><li class="active-result" data-option-array-index="363">Sitapur</li><li class="active-result" data-option-array-index="364">Sivakasi</li><li class="active-result" data-option-array-index="365">Sohna</li><li class="active-result" data-option-array-index="366">Solan</li><li class="active-result" data-option-array-index="367">Solapur</li><li class="active-result" data-option-array-index="368">Somajiguda, Hyderabad.</li><li class="active-result" data-option-array-index="369">Sonbhadra</li><li class="active-result" data-option-array-index="370">Sonepat</li><li class="active-result" data-option-array-index="371">Sonipat</li><li class="active-result" data-option-array-index="372">Sonipat Sub-District</li><li class="active-result" data-option-array-index="373">South</li><li class="active-result" data-option-array-index="374">South Tripura</li><li class="active-result" data-option-array-index="375">Sri Ganganagar</li><li class="active-result" data-option-array-index="376">Sriganganagar</li><li class="active-result" data-option-array-index="377">Srikakulam</li><li class="active-result" data-option-array-index="378">Srinagar</li><li class="active-result" data-option-array-index="379">Srinagar Garhwal</li><li class="active-result" data-option-array-index="380">Surat</li><li class="active-result" data-option-array-index="381">Tamil Nadu</li><li class="active-result" data-option-array-index="382">Tamilpadi</li><li class="active-result" data-option-array-index="383">Tarulia</li><li class="active-result" data-option-array-index="384">Télangana</li><li class="active-result" data-option-array-index="385">Tehri Garhwal</li><li class="active-result" data-option-array-index="386">Telangana</li><li class="active-result" data-option-array-index="387">Telanganapalle</li><li class="active-result" data-option-array-index="388">Tenkasi</li><li class="active-result" data-option-array-index="389">Thalassery</li><li class="active-result" data-option-array-index="390">Thane</li><li class="active-result" data-option-array-index="391">Thanjavur</li><li class="active-result" data-option-array-index="392">Thiruvananthapuram</li><li class="active-result" data-option-array-index="393">Thrissur</li><li class="active-result" data-option-array-index="394">Tiruchirappalli</li><li class="active-result" data-option-array-index="395">Tirunelveli</li><li class="active-result" data-option-array-index="396">Tiruppur</li><li class="active-result" data-option-array-index="397">Tiruvallur</li><li class="active-result" data-option-array-index="398">Tonk</li><li class="active-result" data-option-array-index="399">Trichiana</li><li class="active-result" data-option-array-index="400">Tripura</li><li class="active-result" data-option-array-index="401">Tuljapur</li><li class="active-result" data-option-array-index="402">Tumakuru</li><li class="active-result" data-option-array-index="403">Tumkur</li><li class="active-result" data-option-array-index="404">Turbhe</li><li class="active-result" data-option-array-index="405">Udaipur</li><li class="active-result" data-option-array-index="406">Udham Singh Nagar</li><li class="active-result" data-option-array-index="407">Ujjain</li><li class="active-result" data-option-array-index="408">Ulhasnagar</li><li class="active-result" data-option-array-index="409">Unnao</li><li class="active-result" data-option-array-index="410">Uttar Pradesh</li><li class="active-result" data-option-array-index="411">Uttarakhand</li><li class="active-result" data-option-array-index="412">Vadodara</li><li class="active-result" data-option-array-index="413">Vadodra</li><li class="active-result" data-option-array-index="414">Vallabh Vidhyanagar</li><li class="active-result" data-option-array-index="415">Vallikavu</li><li class="active-result" data-option-array-index="416">Valsad</li><li class="active-result" data-option-array-index="417">Vapi</li><li class="active-result" data-option-array-index="418">Varanasi</li><li class="active-result" data-option-array-index="419">Vasai</li><li class="active-result" data-option-array-index="420">Vasai-Virar</li><li class="active-result" data-option-array-index="421">Vashi</li><li class="active-result" data-option-array-index="422">Vashi Navi Mumbai</li><li class="active-result" data-option-array-index="423">Vatakara</li><li class="active-result" data-option-array-index="424">Vellore</li><li class="active-result" data-option-array-index="425">Veneto</li><li class="active-result" data-option-array-index="426">Vijayapura Town</li><li class="active-result" data-option-array-index="427">Vijayawada</li><li class="active-result" data-option-array-index="428">Vindhyanagar</li><li class="active-result" data-option-array-index="429">Virar</li><li class="active-result" data-option-array-index="430">Virudhunagar</li><li class="active-result" data-option-array-index="431">Visakhapatnam</li><li class="active-result" data-option-array-index="432">Vishakapuram</li><li class="active-result" data-option-array-index="433">Vishakhapatnam</li><li class="active-result" data-option-array-index="434">Vizianagaram</li><li class="active-result" data-option-array-index="435">Wadala</li><li class="active-result" data-option-array-index="436">Wakad</li><li class="active-result" data-option-array-index="437">Warangal</li><li class="active-result" data-option-array-index="438">West Bengal</li><li class="active-result" data-option-array-index="439">West Godavari</li><li class="active-result" data-option-array-index="440">West Tripura</li><li class="active-result" data-option-array-index="441">Yamuna Nagar</li><li class="active-result" data-option-array-index="442">Zirakpur</li></ul></div>'
soup = BeautifulSoup(html2, "html.parser")
job_locations = [location.text.strip() for location in soup.find_all("li", class_="active-result")]
job_locations = pd.DataFrame(job_locations)
job_locations.to_csv("job_locations.csv", index=False)

# %%
def scrape_internshala(keywords, user_location):
    keywords = keywords.replace(" ","-").lower()
    user_location = "-in-"+user_location.replace(" ","-").lower()
    df = pd.DataFrame()
    sequence = 1
    job_links = []
    
    while True and sequence<3:
        url = f"https://internshala.com/jobs/{keywords}-jobs{user_location}/page-{sequence}/"
        response = requests.get(url)
        soup = BeautifulSoup(response.content, "html.parser")
        
        job_titles = [job.text.strip() for job in soup.find_all("h3", class_="heading_4_5 profile")]
        if not job_titles:
            break
        job_links = [a.get("href") for h3 in soup.find_all("h3", class_="heading_4_5 profile") for a in h3.find_all("a")]
        companies = [company.text.strip() for company in soup.find_all("h4", class_="heading_6 company_name")]
        locations = [location.text.strip() for location in soup.find_all("p", id='location_names')]
        salaries = [salary.text.strip() for salary in soup.find_all("div", class_="item_body salary")]
        
        
        experiences = []
        for _ in salaries:
            experiences.append("Check link for info")
        
        min_salary = [salary.split('-')[0].replace('LPA', '').strip() for salary in salaries]
        max_salary = [salary.split('-')[1].replace('LPA', '').strip() if '-' in salary else "N/A" for salary in salaries]
        
        df_temp = pd.DataFrame({"Job Title": job_titles,
                                "Company": companies,
                                "Experience": experiences,
                                "Min Salary (LPA)": min_salary,
                                "Max Salary (LPA)": max_salary,
                                "Location(s)": locations,
                                "Link": job_links})
        
        df = pd.concat([df, df_temp])
        
        sequence += 1
        
    return df.reset_index(drop=True)

# %%
keywords = input("Enter keywords: ")
location = input("Enter location: ")
# Out:
# Enter keywords: Web Development
# Enter location: Delhi

# %%
indf = scrape_internshala(keywords, location)
indf
# Out:
#                                      Job Title  \
# 0                         Full Stack Developer
# 1                            Laravel Developer
# 2                      Junior Python Developer
# 3                      Associate Web Developer
# 4                          Associate SDE (Web)
# 5                                Web Developer
# 6                         Full Stack Developer
# 7                        Website Administrator
# 8                                PHP Developer
# 9                            Node.js Developer
# 10                           Backend Developer
# 11  Junior Web Application Developer (ReactJS)
# 12                 Python And Django Developer
# 13                           Backend Developer
# 14                        Full Stack Developer
# 15                     Associate PHP Developer
# 16                         Front End Developer
# 17                  Junior Front End Developer
# 18                  Senior WordPress Developer
# ...
